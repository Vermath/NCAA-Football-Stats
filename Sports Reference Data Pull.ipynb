# %%
import pandas as pd
import sportsreference as sportsreference
from pprint import pprint

# %%
from sportsreference.nfl.teams import Teams

df=pd.DataFrame()   
teams = []
years = []
for i in range(2002, 2004):
    
    teams = Teams(i)
    for team in teams:
        df = df.append(team.dataframe)
        years.append(i)
    
df["Years"]=years
df
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# KAN          KAN                            -2.3          343
# RAI          RAI                             4.3          366
# NOR          NOR                            -3.3          291
# PHI          PHI                             3.8          311
# ATL          ATL                             1.5          316
# ..           ...                             ...          ...
# HTX          HTX                            -1.5          237
# CLE          CLE                             2.4          276
# NYG          NYG                            -3.7          300
# BUF          BUF                             4.0          268
# CRD          CRD                            -6.2          256
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# KAN                          24        2            16             13       8
# RAI                          27        9            16             10       5
# NOR                          31       15            16             15       7
# PHI                          23       13            16             11       4
# ATL                          30       15            16             12       6
# ..                          ...      ...           ...            ...     ...
# HTX                          24        9            16             18      11
# CLE                          32       15            16             18      11
# NYG                          26       18            16             20      12
# BUF                          22       17            16             17      10
# CRD                          29       14            16             22      12
#
#      margin_of_victory                 name  ...  rush_yards_per_attempt  \
# KAN                4.3   Kansas City Chiefs  ...                     5.1
# RAI                9.1      Oakland Raiders  ...                     4.3
# NOR                2.8   New Orleans Saints  ...                     4.1
# PHI               10.9  Philadelphia Eagles  ...                     4.5
# ATL                5.5      Atlanta Falcons  ...                     4.5
# ..                 ...                  ...  ...                     ...
# HTX               -7.8       Houston Texans  ...                     3.9
# CLE               -4.3     Cleveland Browns  ...                     4.1
# NYG               -9.0      New York Giants  ...                     4.0
# BUF               -2.3        Buffalo Bills  ...                     3.9
# CRD              -14.2    Arizona Cardinals  ...                     3.8
#
#      simple_rating_system  strength_of_schedule  turnovers  win_percentage  \
# KAN                   6.1                   1.9         15           0.500
# RAI                  10.6                   1.5         19           0.688
# NOR                   2.4                  -0.3         30           0.563
# PHI                   8.3                  -2.6         24           0.750
# ATL                   5.1                  -0.4         27           0.594
# ..                    ...                   ...        ...             ...
# HTX                  -6.0                   1.9         27           0.313
# CLE                  -2.9                   1.3         33           0.313
# NYG                  -8.6                   0.4         38           0.250
# BUF                  -1.0                   1.3         34           0.375
# CRD                 -12.6                   1.6         36           0.250
#
#      wins  yards  yards_from_penalties  yards_per_play  Years
# KAN     8   6000                   700             6.2   2002
# RAI    11   6237                  1094             5.8   2002
# NOR     9   5205                   911             5.2   2002
# PHI    12   5604                   897             5.2   2002
# ATL     9   5535                   931             5.3   2002
# ..    ...    ...                   ...             ...    ...
# HTX     5   4306                   961             4.8   2003
# CLE     5   4504                   767             4.7   2003
# NYG     4   4942                  1090             4.7   2003
# BUF     6   4348                   891             4.4   2003
# CRD     4   4490                   761             4.6   2003
#
# [64 rows x 41 columns]
