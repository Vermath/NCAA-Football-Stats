# %%
import pandas as pd
import sportsreference as sportsreference
from pprint import pprint

# %%
from sportsreference.ncaaf.teams import Teams
teams = Teams(2019)
df=pd.DataFrame()

# %%
for team in teams:
    df = df.append(team.dataframe)

# %%
df
# Out:
#                             abbreviation conference conference_losses  \
# CLEMSON                          CLEMSON        acc                 0
# LOUISVILLE                    LOUISVILLE        acc                 3
# WAKE-FOREST                  WAKE-FOREST        acc                 4
# BOSTON-COLLEGE            BOSTON-COLLEGE        acc                 4
# FLORIDA-STATE              FLORIDA-STATE        acc                 4
# ...                                  ...        ...               ...
# LOUISIANA-LAFAYETTE  LOUISIANA-LAFAYETTE   sun-belt                 2
# ARKANSAS-STATE            ARKANSAS-STATE   sun-belt                 3
# LOUISIANA-MONROE        LOUISIANA-MONROE   sun-belt                 4
# TEXAS-STATE                  TEXAS-STATE   sun-belt                 6
# SOUTH-ALABAMA              SOUTH-ALABAMA   sun-belt                 7
#
#                     conference_win_percentage conference_wins  first_downs  \
# CLEMSON                                     1               9         26.2
# LOUISVILLE                              0.625               5         20.2
# WAKE-FOREST                               0.5               4         23.6
# BOSTON-COLLEGE                            0.5               4         21.2
# FLORIDA-STATE                             0.5               4         20.4
# ...                                       ...             ...          ...
# LOUISIANA-LAFAYETTE                     0.778               7         25.1
# ARKANSAS-STATE                          0.625               5         22.1
# LOUISIANA-MONROE                          0.5               4         22.7
# TEXAS-STATE                              0.25               2         16.9
# SOUTH-ALABAMA                           0.125               1         18.0
#
#                      opponents_first_downs  first_downs_from_penalties  \
# CLEMSON                               14.6                         2.5
# LOUISVILLE                            22.0                         1.5
# WAKE-FOREST                           20.8                         1.7
# BOSTON-COLLEGE                        23.5                         0.8
# FLORIDA-STATE                         23.8                         1.9
# ...                                    ...                         ...
# LOUISIANA-LAFAYETTE                   21.1                         1.4
# ARKANSAS-STATE                        24.2                         1.9
# LOUISIANA-MONROE                      23.5                         1.8
# TEXAS-STATE                           21.6                         1.8
# SOUTH-ALABAMA                         21.3                         2.3
#
#                      opponents_first_downs_from_penalties  fumbles_lost  ...  \
# CLEMSON                                               1.3           0.3  ...
# LOUISVILLE                                            1.7           0.8  ...
# WAKE-FOREST                                           1.1           0.3  ...
# BOSTON-COLLEGE                                        1.0           0.5  ...
# FLORIDA-STATE                                         3.2           0.6  ...
# ...                                                   ...           ...  ...
# LOUISIANA-LAFAYETTE                                   2.1           0.7  ...
# ARKANSAS-STATE                                        2.4           0.8  ...
# LOUISIANA-MONROE                                      1.7           0.5  ...
# TEXAS-STATE                                           1.8           0.3  ...
# SOUTH-ALABAMA                                         1.3           0.9  ...
#
#                      turnovers  opponents_turnovers  win_percentage  wins  \
# CLEMSON                    1.0                  2.0           0.933    14
# LOUISVILLE                 1.5                  1.4           0.615     8
# WAKE-FOREST                1.3                  2.0           0.615     8
# BOSTON-COLLEGE             1.0                  1.3           0.462     6
# FLORIDA-STATE              1.6                  1.4           0.462     6
# ...                        ...                  ...             ...   ...
# LOUISIANA-LAFAYETTE        1.0                  1.4           0.786    11
# ARKANSAS-STATE             1.7                  1.5           0.615     8
# LOUISIANA-MONROE           1.5                  1.5           0.417     5
# TEXAS-STATE                2.0                  1.3           0.250     3
# SOUTH-ALABAMA              1.8                  1.3           0.167     2
#
#                      yards opponents_yards  yards_from_penalties  \
# CLEMSON              528.9           288.5                  45.6
# LOUISVILLE           448.0           440.1                  60.0
# WAKE-FOREST          464.0           416.5                  35.4
# BOSTON-COLLEGE       430.2           478.7                  37.0
# FLORIDA-STATE        408.3           424.2                  73.3
# ...                    ...             ...                   ...
# LOUISIANA-LAFAYETTE  494.1           371.9                  58.4
# ARKANSAS-STATE       439.3           477.9                  70.5
# LOUISIANA-MONROE     461.1           483.5                  64.4
# TEXAS-STATE          317.8           416.0                  51.4
# SOUTH-ALABAMA        330.3           408.9                  45.0
#
#                      opponents_yards_from_penalties  yards_per_play  \
# CLEMSON                                        54.9             7.4
# LOUISVILLE                                     40.5             6.7
# WAKE-FOREST                                    56.7             5.7
# BOSTON-COLLEGE                                 41.4             5.8
# FLORIDA-STATE                                  56.7             5.8
# ...                                             ...             ...
# LOUISIANA-LAFAYETTE                            40.4             7.0
# ARKANSAS-STATE                                 57.5             6.2
# LOUISIANA-MONROE                               53.8             6.4
# TEXAS-STATE                                    51.0             5.0
# SOUTH-ALABAMA                                  57.3             5.0
#
#                      opponents_yards_per_play
# CLEMSON                                   4.5
# LOUISVILLE                                6.3
# WAKE-FOREST                               5.8
# BOSTON-COLLEGE                            6.3
# FLORIDA-STATE                             5.3
# ...                                       ...
# LOUISIANA-LAFAYETTE                       5.5
# ARKANSAS-STATE                            6.1
# LOUISIANA-MONROE                          6.7
# TEXAS-STATE                               5.7
# SOUTH-ALABAMA                             5.8
#
# [130 rows x 56 columns]

# %%
# To Do
# Build database diagram
# Move into SQL database
